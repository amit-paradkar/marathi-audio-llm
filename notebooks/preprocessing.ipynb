# %%
import sys
sys.path.append('/content/marathi-audio-llm')

from scripts.preprocess_audio import load_audio
from scripts.preprocess_audio import chunk_audio

sample = load_audio("data/raw/sample.wav")

chunks = chunk_audio(sample)

print(chunks.shape)
